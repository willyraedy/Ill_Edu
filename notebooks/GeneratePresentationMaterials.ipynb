# %%
Payson CUSD 1	41.2	44.1	14.7	0.0

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(5, 10))

level_1 = 41.2
level_2 = 44.1
level_3 = 14.7
level_4 = 0

label = 'Payson CUSD'

csfont = {'fontname':'Source Sans Pro'}


plt.bar(label, level_1, color='tab:red')
plt.bar(label, level_2, bottom=level_1, color='tab:gray')
plt.bar(label, level_3, bottom=(level_1 + level_2), color='tab:green')
plt.bar(label, level_4, bottom=(level_1 + level_2 + level_3), color='tab:purple')

plt.legend(['Level 1', 'Level 2', 'Level 3', 'Level 4'], bbox_to_anchor=(0.97, .95), fontsize='25')
plt.xticks(fontsize='25', fontname='Source Sans Pro')
plt.title('SAT Math Performance', fontsize='45', fontname='Source Sans Pro')
plt.yticks([])
plt.box(on=None)

plt.savefig('../presentation_materials/ex_sat_score.jpg', format='jpg', quality=95)

# %%
((1 * level_1) + (2 * level_2) + (3 * level_3) + (4 * level_4)) / 100
# Out:
# 1.735
